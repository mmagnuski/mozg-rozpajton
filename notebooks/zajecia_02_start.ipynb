# %%
import os
import os.path as op


import mne
from mne.io import read_raw_egiaw

# %%
# ścieżka do plików, podaj poprawną:
base_dir = r'C:\Users\swps\Dropbox\DANE\CAT N170\EEG\RAW'

# tworzymy listę plików
files = os.listdir(base_dir)
files[:3]
# Out:
# ['CAT101 20130518 1906002.raw',
#  'CAT106 20131027 1538002.raw',
#  'CAT107 20131027 1648002.raw']

# %%
# wybieramy nazwę pliku i zapisujemy w zmiennej `file`
file = files[4]
print(file)
# Out:
# CAT110 20131108 2040002.raw

# %%
# łączymy nazwę pliku i ścieżkę:
file_path = op.join(base_dir, file)

# wczytujemy plik
raw = read_raw_egi(file_path, preload=True)
print(raw)
# Out:
# Reading EGI header from C:\Users\swps\Dropbox\DANE\CAT N170\EEG\RAW\CAT110 20131108 2040002.raw...
#     Reading events ...
#     Assembling measurement info ...
#     Synthesizing trigger channel "STI 014" ...
#     Excluding events {} ...
#     Found multiple events at the same time sample. Cannot create trigger channel.
# Reading 0 ... 177498  =      0.000 ...   709.992 secs...
# <RawEGI  |  CAT110 20131108 2040002.raw, n_channels x n_times : 73 x 177499 (710.0 sec), ~99.0 MB, data loaded>

# %%
# uruchamiamy tryb interaktywny plotowania
# %matplotlib
# Out:
# Using matplotlib backend: Qt4Agg

# %%
# wyświetlamy dane
raw.plot()
# Out:
# C:\Anaconda3\lib\site-packages\matplotlib\collections.py:360: UserWarning: Collection picker None could not be converted to float
#   % self._picker)
