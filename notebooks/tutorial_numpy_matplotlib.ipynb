# %%
import numpy as np

# %%
a = [3, 6, 1, 2, 7]

# %%
A = np.array(a)

# %%
A
# Out:
# array([3, 6, 1, 2, 7])

# %%
A[[0, 1, -1]]
# Out:
# array([3, 6, 7])

# %%
A.dtype
# Out:
# dtype('int32')

# %%
b = [3, 6.2, 1, 2, 7]
B = np.array(b)

# %%
B.dtype
# Out:
# dtype('float64')

# %%
b = [2.1, 4.7, 2.3, 7.9, 6.1]
B = np.array(b)
B
# Out:
# array([ 2.1,  4.7,  2.3,  7.9,  6.1])

# %%
['ala', 'ma'] + ['kota']
# Out:
# ['ala', 'ma', 'kota']

# %%
A + B
# Out:
# array([  5.1,  10.7,   3.3,   9.9,  13.1])

# %% [markdown]
# ### macierze (2d)

# %%
R = np.random.rand(5, 5)
R
# Out:
# array([[ 0.63378133,  0.95690114,  0.82811758,  0.20183497,  0.13768328],
#        [ 0.87937428,  0.98925212,  0.0145248 ,  0.6556111 ,  0.89125153],
#        [ 0.5797434 ,  0.44189296,  0.81060472,  0.78695897,  0.49623914],
#        [ 0.2840506 ,  0.82014984,  0.66853625,  0.05107612,  0.72053633],
#        [ 0.12525002,  0.10392644,  0.99430477,  0.5348942 ,  0.8246358 ]])

# %%
R[2, :]
# Out:
# array([ 0.5797434 ,  0.44189296,  0.81060472,  0.78695897,  0.49623914])

# %%
R = np.random.rand(6, 4)

# %%
R
# Out:
# array([[ 0.6641475 ,  0.61098314,  0.73402588,  0.42031842],
#        [ 0.33034569,  0.74206082,  0.54979866,  0.90581923],
#        [ 0.47286703,  0.31328137,  0.75655377,  0.4512889 ],
#        [ 0.70648494,  0.11064697,  0.74362661,  0.69094551],
#        [ 0.71184606,  0.59487851,  0.38746178,  0.08970054],
#        [ 0.42827382,  0.50578385,  0.91914395,  0.36335337]])

# %%
R.mean(axis=1)
# Out:
# array([ 0.60736873,  0.6320061 ,  0.49849777,  0.56292601,  0.44597172,
#         0.55413875])

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
eeg = np.random.rand(5, 100)

# %%
plt.plot(eeg[2, :])

# %%
plt.plot(eeg.T);

# %%
plt.imshow(eeg, aspect='auto', interpolation='none')
plt.colorbar()

# %%
plt.matshow(eeg, aspect='auto')
